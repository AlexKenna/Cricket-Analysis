# %% [markdown]
# # Data Exploration
# This document explores the raw data to determine what must be cleaned before modelling can begin. The data initialisation notebook was made in parallel with this document, exposing the inconsistencies and areas for improvement in the raw dataset.

# %%
# Perform necessary imports.
import pandas as pd
from lib.constants import *

# %% [markdown]
# ## Exploring Match Data
# In this section, we will explore the raw match data.

# %%
# Load match data.
match_data = pd.read_csv(DATA_PATH + "/Matches.txt", delimiter="\t")

# %% [markdown]
# 1. Exploring the columns of the match data.

# %%
# Print the columns of match data.
match_data.columns
# Out:
# Index(['Match Id', 'Season Id', 'Season', 'Series Id', 'Series',
#        'Series Gender Id', 'Series Gender', 'Match Date', 'Match YYMMDD',
#        'Match Type Id', 'Match Type', 'Ball Type Id', 'Ball Type', 'TeamA Id',
#        'TeamA', 'TeamA At Home', 'TeamB Id', 'TeamB', 'TeamB At Home',
#        'Day/Night', 'Venue Id', 'Venue', 'Toss Won By Id', 'Toss Decision Id',
#        'TeamA Innings1 Closure', 'TeamA Innings2 Closure',
#        'TeamB Innings1 Closure', 'TeamB Innings2 Closure',
#        'TeamA 1st Comparison', 'TeamA Result Id', 'TeamA Result',
#        'TeamBattingIdMatchInnings1', 'TeamBattingMatchInnings1',
#        'TeamBattingIdMatchInnings2', 'TeamBattingMatchInnings2',
#        'TeamBattingIdMatchInnings3', 'TeamBattingMatchInnings3',
#        'TeamBattingIdMatchInnings4', 'TeamBattingMatchInnings4',
#        'TeamB Result Id', 'TeamB Result', 'TeamA Coach Id',
#        'TeamA Coach Surname', 'TeamA Coach Other Names', 'TeamB Coach Id',
#        'TeamB Coach Surname', 'TeamB Coach Other Names', 'Round Id', 'Round',
#        'Round Number', 'Match Number', 'Data Source', 'Official1 Id',
#        'Official1 Surname', 'Official1 Other Names', 'Official2 Id',
#        'Official2 Surname', 'Official2 Other Names', 'Official3 Id',
#        'Official3 Surname', 'Official3 Other Names', 'Official4 Id',
#        'Official4 Surname', 'Official4 Other Names', 'Official5 Id',
#        'Official5 Surname', 'Official5 Other Names', 'Official6 Id',
#        'Official6 Surname', 'Official6 Other Names'],
#       dtype='object')

# %% [markdown]
# From this, and for the purpose of this project, it appears that the Official's columns is redundant and could be removed for the purpose of data management.
#
# 2. Explore series gender.

# %%
# Print series gender.
match_data["Series Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# Print series gender ID.
match_data["Series Gender Id"].unique()
# Out:
# array([1, 2], dtype=int64)

# %% [markdown]
# For this project, we only need to focus on the male formats of cricket as we are attempting to model their performance. For the reasoning behind this can be read in the overview document.
#
# 3. Explore teams.

# %%
# Print all recorded teams.
match_data["TeamA"].unique()
# Out:
# array(['Australia (M)', 'West Indies (M)', 'Pakistan (M)',
#        'Sri Lanka (M)', 'South Africa (M)', 'England (M)',
#        'New Zealand (M)', 'India (M)', 'SA (M)', 'Tas (M)', 'NSW (M)',
#        'Victoria (M)', 'WA (M)', 'Aus Intellectual Disability', 'Qld (M)',
#        'Australia (F)', 'WA (F)', 'Qld Fire (F)', 'New Zealand (F)',
#        'NSW Breakers (F)', 'Southern Scorpions (F)', 'Australia A (M)',
#        'Zimbabwe (M)', 'Kenya (M)', 'ACT Meteors (F)', 'Victoria (F)',
#        'England (F)', 'Scotland (M)', 'Bangladesh (M)', 'Ireland (M)',
#        'India (F)', 'West Indies (F)', 'Tasmania Tigers (F)',
#        'Sydney Sixers (M)', 'Melbourne Stars (M)',
#        'Adelaide Strikers (M)', 'Perth Scorchers  (M)',
#        'Brisbane Heat (M)', 'Hobart Hurricanes (M)',
#        'Melbourne Renegades (M)', 'Sydney Thunder (M)', 'Canada (M)',
#        'Gloucestershire (M)', 'South Africa Women (F)', 'Afghanistan (M)',
#        'India A (M)', 'South Africa A (M)', 'Pakistan (F)',
#        'Sri Lanka (F)', 'Supernovas (F)', 'Southern Vipers (F)',
#        'Surrey Stars (F)', 'Western Storm (F)', 'Yorkshire Diamonds (F)',
#        'Lancashire Thunder (F)', 'Loughborough Lightning (F)',
#        'Bangladesh (F)', 'Ireland (F)', 'CA XI (M)', 'Brisbane Heat (F)',
#        'Melbourne Stars (F)', 'Sydney Thunder (F)', 'Perth Scorchers (F)',
#        'Melbourne Renegades (F)', 'Hobart Hurricanes (F)',
#        'Sydney Sixers (F)', 'Adelaide Strikers (F)', 'India B (M)',
#        'Thailand (F)', 'Scotland (F)', 'Namibia (F)', 'Australia A (F)',
#        'England Lions (M)', 'India A (F)'], dtype=object)

# %% [markdown]
# The only team that appears to need to be removed from this list is "Aus Intellectual Disability". The reasoning for removing this team can be read about in the overview document.
#
# 4. Check international games.

# %%
# Check for international games where Australia is not playing.
match_data[match_data.Series.str.contains("International") & ~match_data.TeamA.str.contains("Australia") & ~match_data.TeamB.str.contains("Australia")][["TeamA", "TeamB"]]
# Out:
#                  TeamA            TeamB
# 19     West Indies (M)     Zimbabwe (M)
# 75       Sri Lanka (M)      England (M)
# 76       Sri Lanka (M)      England (M)
# 77       Sri Lanka (M)      England (M)
# 78    South Africa (M)    Sri Lanka (M)
# ...                ...              ...
# 4018         India (M)      England (M)
# 4019         India (M)      England (M)
# 4020         India (M)      England (M)
# 4021         India (M)      England (M)
# 4022       England (F)  New Zealand (F)
#
# [429 rows x 2 columns]

# %%
# Check number of international games where Australia is not playing.
len(match_data[match_data.Series.str.contains("International") & ~match_data.TeamA.str.contains("Australia") & ~match_data.TeamB.str.contains("Australia")][["TeamA", "TeamB"]])
# Out:
# 429

# %% [markdown]
# 5. Explore match format length.

# %%
# Print match types.
match_data["Match Type"].unique()
# Out:
# array(['5 Day', '1 Day', '4 Day', 'Twenty20', '3 Day', '2 Day'],
#       dtype=object)

# %%
# Print match type Ids.
match_data["Match Type Id"].unique()
# Out:
# array([5, 1, 4, 7, 3, 2], dtype=int64)

# %% [markdown]
# At the top level, T20, 1 Day, and 5 Day are the only formats played consistently. However, domestically, 4 Day formats are preferred over 5 day. Hence, we will only keep T20, 1 Day, 4 Day, and 5 Day formats.
#
# 6. Check for columns containing NaN.

# %%
# Print columns containing NaN.
match_data.columns[match_data.isna().any()].tolist()
# Out:
# ['TeamBattingMatchInnings1',
#  'TeamBattingMatchInnings2',
#  'TeamBattingMatchInnings3',
#  'TeamBattingMatchInnings4',
#  'TeamA Coach Id',
#  'TeamA Coach Surname',
#  'TeamA Coach Other Names',
#  'TeamB Coach Id',
#  'TeamB Coach Surname',
#  'TeamB Coach Other Names',
#  'Data Source',
#  'Official1 Id',
#  'Official1 Surname',
#  'Official1 Other Names',
#  'Official2 Id',
#  'Official2 Surname',
#  'Official2 Other Names',
#  'Official3 Id',
#  'Official3 Surname',
#  'Official3 Other Names',
#  'Official4 Id',
#  'Official4 Surname',
#  'Official4 Other Names',
#  'Official5 Id',
#  'Official5 Surname',
#  'Official5 Other Names',
#  'Official6 Id',
#  'Official6 Surname',
#  'Official6 Other Names']

# %% [markdown]
# From this, we can see we have already removed the majority of these fields by removing Officials. While it could be reasonable to remove other fields such as "Data Source" or Coach fields, we will leave these for now.
#
# 7. Check for duplicate rows.

# %%
# Print duplicate rows.
match_data[match_data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Match Id, Season Id, Season, Series Id, Series, Series Gender Id, Series Gender, Match Date, Match YYMMDD, Match Type Id, Match Type, Ball Type Id, Ball Type, TeamA Id, TeamA, TeamA At Home, TeamB Id, TeamB, TeamB At Home, Day/Night, Venue Id, Venue, Toss Won By Id, Toss Decision Id, TeamA Innings1 Closure, TeamA Innings2 Closure, TeamB Innings1 Closure, TeamB Innings2 Closure, TeamA 1st Comparison, TeamA Result Id, TeamA Result, TeamBattingIdMatchInnings1, TeamBattingMatchInnings1, TeamBattingIdMatchInnings2, TeamBattingMatchInnings2, TeamBattingIdMatchInnings3, TeamBattingMatchInnings3, TeamBattingIdMatchInnings4, TeamBattingMatchInnings4, TeamB Result Id, TeamB Result, TeamA Coach Id, TeamA Coach Surname, TeamA Coach Other Names, TeamB Coach Id, TeamB Coach Surname, TeamB Coach Other Names, Round Id, Round, Round Number, Match Number, Data Source, Official1 Id, Official1 Surname, Official1 Other Names, Official2 Id, Official2 Surname, Official2 Other Names, Official3 Id, Official3 Surname, Official3 Other Names, Official4 Id, Official4 Surname, Official4 Other Names, Official5 Id, Official5 Surname, Official5 Other Names, Official6 Id, Official6 Surname, Official6 Other Names]
# Index: []
#
# [0 rows x 70 columns]

# %% [markdown]
# So, there are no duplicate rows.
#
# 8. Explore series.

# %%
# Print series out.
match_data.Series.unique()
# Out:
# array(['International Tests M', 'International ODI M',
#        'Domestic 1st Class M', 'Domestic List A M', 'International T20 M',
#        'Domestic T20 M', 'International ICC Trophy M',
#        'International ODI World Cup M', 'International ODI F',
#        'International T20 F', 'Domestic OD F',
#        'International T20 World Cup M', 'Domestic T20 F',
#        'International ODI World Cup F', 'International T20 World Cup F',
#        'International Tests F', 'International 1st Class M',
#        'International 1st Class F'], dtype=object)

# %% [markdown]
# ## Exploring Delivery Data
# In this section, we will explore the raw deliveries data.
#
# To begin with, we must load the deliveries data. However, we will load the file in chunks, removing any delivery data not related to the curated set of matches outlined above.

# %%
# Load cleaned match data.
match_data = pd.read_csv(DATA_PATH + "/Matches_Clean.txt", delimiter="\t")

# Determine which matches are important for delivery data.
match_ids = match_data["Match Id"]

# Determine duplicate columns between match and delivery data that should be dropped.
match_columns = set(match_data.columns)
match_columns.remove("Match Id")

# Load delivery data
delivery_data = pd.DataFrame()

for chunk in pd.read_csv(DATA_PATH + "/Deliveries.txt", delimiter="\t", chunksize=10**6):
  chunk = chunk[chunk["Match Id"].isin(match_ids)]
  chunk.drop(
    [col for col in chunk.columns if col in match_columns], axis=1, inplace=True
  )

  # Combine filtered deliveries into single dataframe.
  delivery_data = pd.concat([delivery_data, chunk])
# Out:
# C:\Users\AlexK\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3377: DtypeWarning: Columns (6,19,85,87,101,103,200,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,233,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,396) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\AlexK\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3377: DtypeWarning: Columns (6,19,56,85,87,91,101,103,169,200,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,233,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,266,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,396) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\AlexK\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3377: DtypeWarning: Columns (6,19,56,85,87,89,91,101,103,112,114,116,118,120,169,200,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,233,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,266,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,299,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,332,360,363,364,366,367,389,390,396) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %% [markdown]
# 1. Explore delivery columns.

# %%
# Print delivery columns.
list(delivery_data.columns)
# Out:
# ['Match Id',
#  'Team Batting At Home',
#  'Team Bowling At Home',
#  'Toss Won By Team',
#  'Toss Won By Batting Team',
#  'Toss Decision',
#  'TeamA ResultId',
#  'Team Batting Id',
#  'Team Batting',
#  'Team Bowling Id',
#  'Team Bowling',
#  'Innings',
#  'Delivery',
#  'Day',
#  'Session',
#  'Time of Day (Hour)',
#  'Time of Day (Min)',
#  'Time of Day',
#  'Striker Id',
#  'Striker',
#  'Striker Hand Id',
#  'Striker Hand',
#  'Non Striker Id',
#  'Non Striker',
#  'Non Striker Hand Id',
#  'Non Striker Hand',
#  'Bowler Id',
#  'Bowler',
#  'Bowler Hand Id',
#  'Bowler Hand',
#  'Pace / Spin',
#  'Bowler Style',
#  'Spell',
#  'Over The Wicket',
#  'Northern End',
#  'Power Play',
#  'Over',
#  'Ball In Over',
#  'Fair Ball In Over',
#  'Ball Speed',
#  'Ball RPM',
#  'Pitch X',
#  'Pitch Y',
#  'At Batter X',
#  'At Batter Y',
#  'At Stumps X',
#  'At Stumps Y',
#  'Hit To Len',
#  'Hit To Angle',
#  'Bat Score',
#  'ReachedBoundary',
#  'Wides',
#  'Noballs',
#  'Byes',
#  'Legbyes',
#  'Penalty Runs',
#  'Taken By WK',
#  'Batter Out Id',
#  'Batter Out',
#  'How Out',
#  'Fielder1 Id',
#  'Fielder1',
#  'Fielder2 Id',
#  'Fielder2',
#  'Fielder3 Id',
#  'Fielder3',
#  'Fielder4 Id',
#  'Fielder4',
#  'Fielder5 Id',
#  'Fielder5',
#  'MatchInnings',
#  'TeamB ResultId',
#  'Team Batting ResultId',
#  'Team Batting Result',
#  'Team Bowling ResultId',
#  'Team Bowling Result',
#  'Temperature Id',
#  'Temperature Description',
#  'Humidity Id',
#  'Humidity Description',
#  'Wind Id',
#  'Wind Description',
#  'Cloud Cover Id',
#  'Cloud Cover Description',
#  'Cloud Colour Id',
#  'Cloud Colour Description',
#  'Inside Edge',
#  'Outside Edge',
#  'Play and Miss',
#  'Hit on Pads',
#  'Hit on Head',
#  'Hit on Body',
#  'Contact Error',
#  'Opportunity',
#  'Retired Hurt',
#  'Appeal',
#  'Bowler Variation',
#  'Batter Movement',
#  'Sweep Shot',
#  'Ramp or Paddle Shot',
#  'Reverse or Switch Shot',
#  'Umpire Referral',
#  'DRS Bowler Won',
#  'DRS Bowler Lost',
#  'DRS Bowler Lost Umpire',
#  'DRS Striker Won',
#  'DRS Striker Lost',
#  'DRS Striker Lost Umpire',
#  'Individual 50',
#  'Individual 100',
#  'Individual 150',
#  'Individual 200',
#  'Individual 250',
#  'Individual 300',
#  'Partnership 50',
#  'Partnership 100',
#  'Partnership 150',
#  'Partnership 200',
#  'Partnership 250',
#  'Partnership 300',
#  'Coding Review Required',
#  'Injury Striker Head',
#  'Injury Striker Other',
#  'Injury Non Striker Head',
#  'Injury Non Striker Other',
#  'Injury Bowler Head',
#  'Injury Bowler Other',
#  'Injury Keeper Head',
#  'Injury Keeper Other',
#  'Injury Fielder Head',
#  'Injury Fielder Other',
#  'Injury Umpire Head',
#  'Injury Umpire Other',
#  'Event Grade',
#  'Event Infield',
#  'Fielder1 Catch',
#  'Fielder1 Catch Assist',
#  'Fielder1 Dropped Catch',
#  'Fielder1 Runout',
#  'Fielder1 Runout Missed',
#  'Fielder1 Runout Assist',
#  'Fielder1 Runout Assist Missed',
#  'Fielder1 Missed Stumping',
#  'Fielder1 Extra Effort',
#  'Fielder1 Pressure Field',
#  'Fielder1 Assist',
#  'Fielder1 Fumble',
#  'Fielder1 Misfield',
#  'Fielder1 Dive Stop',
#  'Fielder1 Dive Misfield',
#  'Fielder1 Slide Stop',
#  'Fielder1 Slide Miss',
#  'Fielder1 Throw',
#  'Fielder1 Good Throw',
#  'Fielder1 Error Throw',
#  'Fielder1 Throw Hit',
#  'Fielder1 Throw Miss',
#  'Fielder1 Throw Backed Up',
#  'Fielder1 Throw Not Backed Up',
#  'Fielder1 Keeper Drop',
#  'Fielder1 Keeper Fumble',
#  'Fielder1 Keeper Dive Stop',
#  'Fielder1 Keeper Missed Stumping',
#  'Fielder1 Keeper Leg Side',
#  'Fielder1 Event Grade',
#  'Fielder1 Event Infield',
#  'Fielder1 Runs Cost',
#  'Fielder1 Runs Saved',
#  'Fielder2 Catch',
#  'Fielder2 Catch Assist',
#  'Fielder2 Dropped Catch',
#  'Fielder2 Runout',
#  'Fielder2 Runout Missed',
#  'Fielder2 Runout Assist',
#  'Fielder2 Runout Assist Missed',
#  'Fielder2 Missed Stumping',
#  'Fielder2 Extra Effort',
#  'Fielder2 Pressure Field',
#  'Fielder2 Assist',
#  'Fielder2 Fumble',
#  'Fielder2 Misfield',
#  'Fielder2 Dive Stop',
#  'Fielder2 Dive Misfield',
#  'Fielder2 Slide Stop',
#  'Fielder2 Slide Miss',
#  'Fielder2 Throw',
#  'Fielder2 Good Throw',
#  'Fielder2 Error Throw',
#  'Fielder2 Throw Hit',
#  'Fielder2 Throw Miss',
#  'Fielder2 Throw Backed Up',
#  'Fielder2 Throw Not Backed Up',
#  'Fielder2 Keeper Drop',
#  'Fielder2 Keeper Fumble',
#  'Fielder2 Keeper Dive Stop',
#  'Fielder2 Keeper Missed Stumping',
#  'Fielder2 Keeper Leg Side',
#  'Fielder2 Event Grade',
#  'Fielder2 Event Infield',
#  'Fielder2 Runs Cost',
#  'Fielder2 Runs Saved',
#  'Fielder3 Catch',
#  'Fielder3 Catch Assist',
#  'Fielder3 Dropped Catch',
#  'Fielder3 Runout',
#  'Fielder3 Runout Missed',
#  'Fielder3 Runout Assist',
#  'Fielder3 Runout Assist Missed',
#  'Fielder3 Missed Stumping',
#  'Fielder3 Extra Effort',
#  'Fielder3 Pressure Field',
#  'Fielder3 Assist',
#  'Fielder3 Fumble',
#  'Fielder3 Misfield',
#  'Fielder3 Dive Stop',
#  'Fielder3 Dive Misfield',
#  'Fielder3 Slide Stop',
#  'Fielder3 Slide Miss',
#  'Fielder3 Throw',
#  'Fielder3 Good Throw',
#  'Fielder3 Error Throw',
#  'Fielder3 Throw Hit',
#  'Fielder3 Throw Miss',
#  'Fielder3 Throw Backed Up',
#  'Fielder3 Throw Not Backed Up',
#  'Fielder3 Keeper Drop',
#  'Fielder3 Keeper Fumble',
#  'Fielder3 Keeper Dive Stop',
#  'Fielder3 Keeper Missed Stumping',
#  'Fielder3 Keeper Leg Side',
#  'Fielder3 Event Grade',
#  'Fielder3 Event Infield',
#  'Fielder3 Runs Cost',
#  'Fielder3 Runs Saved',
#  'Fielder4 Catch',
#  'Fielder4 Catch Assist',
#  'Fielder4 Dropped Catch',
#  'Fielder4 Runout',
#  'Fielder4 Runout Missed',
#  'Fielder4 Runout Assist',
#  'Fielder4 Runout Assist Missed',
#  'Fielder4 Missed Stumping',
#  'Fielder4 Extra Effort',
#  'Fielder4 Pressure Field',
#  'Fielder4 Assist',
#  'Fielder4 Fumble',
#  'Fielder4 Misfield',
#  'Fielder4 Dive Stop',
#  'Fielder4 Dive Misfield',
#  'Fielder4 Slide Stop',
#  'Fielder4 Slide Miss',
#  'Fielder4 Throw',
#  'Fielder4 Good Throw',
#  'Fielder4 Error Throw',
#  'Fielder4 Throw Hit',
#  'Fielder4 Throw Miss',
#  'Fielder4 Throw Backed Up',
#  'Fielder4 Throw Not Backed Up',
#  'Fielder4 Keeper Drop',
#  'Fielder4 Keeper Fumble',
#  'Fielder4 Keeper Dive Stop',
#  'Fielder4 Keeper Missed Stumping',
#  'Fielder4 Keeper Leg Side',
#  'Fielder4 Event Grade',
#  'Fielder4 Event Infield',
#  'Fielder4 Runs Cost',
#  'Fielder4 Runs Saved',
#  'Fielder5 Catch',
#  'Fielder5 Catch Assist',
#  'Fielder5 Dropped Catch',
#  'Fielder5 Runout',
#  'Fielder5 Runout Missed',
#  'Fielder5 Runout Assist',
#  'Fielder5 Runout Assist Missed',
#  'Fielder5 Missed Stumping',
#  'Fielder5 Extra Effort',
#  'Fielder5 Pressure Field',
#  'Fielder5 Assist',
#  'Fielder5 Fumble',
#  'Fielder5 Misfield',
#  'Fielder5 Dive Stop',
#  'Fielder5 Dive Misfield',
#  'Fielder5 Slide Stop',
#  'Fielder5 Slide Miss',
#  'Fielder5 Throw',
#  'Fielder5 Good Throw',
#  'Fielder5 Error Throw',
#  'Fielder5 Throw Hit',
#  'Fielder5 Throw Miss',
#  'Fielder5 Throw Backed Up',
#  'Fielder5 Throw Not Backed Up',
#  'Fielder5 Keeper Drop',
#  'Fielder5 Keeper Fumble',
#  'Fielder5 Keeper Dive Stop',
#  'Fielder5 Keeper Missed Stumping',
#  'Fielder5 Keeper Leg Side',
#  'Fielder5 Event Grade',
#  'Fielder5 Event Infield',
#  'Fielder5 Runs Cost',
#  'Fielder5 Runs Saved',
#  'Cum Inning Balls',
#  'Cum Inning Bat Score',
#  'Cum Inning Noballs',
#  'Cum Inning Noball Runs',
#  'Cum Inning Wides',
#  'Cum Inning Wide Runs',
#  'Cum Inning Byes',
#  'Cum Inning Legbyes',
#  'Cum Inning Penalty Runs',
#  'Cum Inning Extras',
#  'Cum Inning Score',
#  'Cum Inning Wickets',
#  'Cum Striker Balls',
#  'Cum Striker Runs',
#  'Cum Non Striker Balls',
#  'Cum Non Striker Runs',
#  'Cum Partnership Balls',
#  'Cum Partnership Runs',
#  'Cum Bowler Balls',
#  'Cum Bowler Runs',
#  'Pitch X Coded',
#  'Pitch Y Coded',
#  'At Batter X Coded',
#  'At Batter Y Coded',
#  'Free Hit',
#  'Time of Day (Sec)',
#  'Time of Day (Full)',
#  'Video Start Time UTC',
#  'Video Stop Time UTC',
#  'Video UTC Offset Minutes',
#  'Video Start Time Local',
#  'Video Stop Time Local',
#  'Striker Batting Position',
#  'Non Striker Batting Position',
#  'Bowler Bowling Position',
#  'Hit To Octant',
#  'Hit To Octant Description',
#  'Pitch X Description',
#  'Pitch Y Description',
#  'Pitch X Coded Description',
#  'Pitch Y Coded Description',
#  'Release X',
#  'Release Y',
#  'Release Z',
#  'Release Speed',
#  'Release Angle',
#  'Drop Speed',
#  'Drop Angle',
#  'Bounce Speed',
#  'Bounce Angle',
#  'Movement In Air',
#  'Movement Off Pitch',
#  'Stump Speed',
#  'Shot Aggression',
#  'Shot Quality Description',
#  'Hit To X Physical',
#  'Hit To Y Physical',
#  'Video File Name',
#  'Video Mark In Milliseconds',
#  'Keeper Id',
#  'Keeper']

# %% [markdown]
# We can't really see much from this. Instead, we will check for columns that contains NaN.
#
# 2. Check for columns containing NaN.

# %%
# Check columns that contain NaN
delivery_data.columns[delivery_data.isna().any()].tolist()
# Out:
# ['Toss Won By Team',
#  'Ball Speed',
#  'Ball RPM',
#  'Batter Out Id',
#  'Batter Out',
#  'How Out',
#  'Fielder1 Id',
#  'Fielder1',
#  'Fielder2 Id',
#  'Fielder2',
#  'Fielder3 Id',
#  'Fielder3',
#  'Fielder4 Id',
#  'Fielder4',
#  'Fielder5 Id',
#  'Fielder5',
#  'Wind Description',
#  'Event Grade',
#  'Event Infield',
#  'Fielder1 Catch',
#  'Fielder1 Catch Assist',
#  'Fielder1 Dropped Catch',
#  'Fielder1 Runout',
#  'Fielder1 Runout Missed',
#  'Fielder1 Runout Assist',
#  'Fielder1 Runout Assist Missed',
#  'Fielder1 Missed Stumping',
#  'Fielder1 Extra Effort',
#  'Fielder1 Pressure Field',
#  'Fielder1 Assist',
#  'Fielder1 Fumble',
#  'Fielder1 Misfield',
#  'Fielder1 Dive Stop',
#  'Fielder1 Dive Misfield',
#  'Fielder1 Slide Stop',
#  'Fielder1 Slide Miss',
#  'Fielder1 Throw',
#  'Fielder1 Good Throw',
#  'Fielder1 Error Throw',
#  'Fielder1 Throw Hit',
#  'Fielder1 Throw Miss',
#  'Fielder1 Throw Backed Up',
#  'Fielder1 Throw Not Backed Up',
#  'Fielder1 Keeper Drop',
#  'Fielder1 Keeper Fumble',
#  'Fielder1 Keeper Dive Stop',
#  'Fielder1 Keeper Missed Stumping',
#  'Fielder1 Keeper Leg Side',
#  'Fielder1 Event Grade',
#  'Fielder1 Event Infield',
#  'Fielder1 Runs Cost',
#  'Fielder1 Runs Saved',
#  'Fielder2 Catch',
#  'Fielder2 Catch Assist',
#  'Fielder2 Dropped Catch',
#  'Fielder2 Runout',
#  'Fielder2 Runout Missed',
#  'Fielder2 Runout Assist',
#  'Fielder2 Runout Assist Missed',
#  'Fielder2 Missed Stumping',
#  'Fielder2 Extra Effort',
#  'Fielder2 Pressure Field',
#  'Fielder2 Assist',
#  'Fielder2 Fumble',
#  'Fielder2 Misfield',
#  'Fielder2 Dive Stop',
#  'Fielder2 Dive Misfield',
#  'Fielder2 Slide Stop',
#  'Fielder2 Slide Miss',
#  'Fielder2 Throw',
#  'Fielder2 Good Throw',
#  'Fielder2 Error Throw',
#  'Fielder2 Throw Hit',
#  'Fielder2 Throw Miss',
#  'Fielder2 Throw Backed Up',
#  'Fielder2 Throw Not Backed Up',
#  'Fielder2 Keeper Drop',
#  'Fielder2 Keeper Fumble',
#  'Fielder2 Keeper Dive Stop',
#  'Fielder2 Keeper Missed Stumping',
#  'Fielder2 Keeper Leg Side',
#  'Fielder2 Event Grade',
#  'Fielder2 Event Infield',
#  'Fielder2 Runs Cost',
#  'Fielder2 Runs Saved',
#  'Fielder3 Catch',
#  'Fielder3 Catch Assist',
#  'Fielder3 Dropped Catch',
#  'Fielder3 Runout',
#  'Fielder3 Runout Missed',
#  'Fielder3 Runout Assist',
#  'Fielder3 Runout Assist Missed',
#  'Fielder3 Missed Stumping',
#  'Fielder3 Extra Effort',
#  'Fielder3 Pressure Field',
#  'Fielder3 Assist',
#  'Fielder3 Fumble',
#  'Fielder3 Misfield',
#  'Fielder3 Dive Stop',
#  'Fielder3 Dive Misfield',
#  'Fielder3 Slide Stop',
#  'Fielder3 Slide Miss',
#  'Fielder3 Throw',
#  'Fielder3 Good Throw',
#  'Fielder3 Error Throw',
#  'Fielder3 Throw Hit',
#  'Fielder3 Throw Miss',
#  'Fielder3 Throw Backed Up',
#  'Fielder3 Throw Not Backed Up',
#  'Fielder3 Keeper Drop',
#  'Fielder3 Keeper Fumble',
#  'Fielder3 Keeper Dive Stop',
#  'Fielder3 Keeper Missed Stumping',
#  'Fielder3 Keeper Leg Side',
#  'Fielder3 Event Grade',
#  'Fielder3 Event Infield',
#  'Fielder3 Runs Cost',
#  'Fielder3 Runs Saved',
#  'Fielder4 Catch',
#  'Fielder4 Catch Assist',
#  'Fielder4 Dropped Catch',
#  'Fielder4 Runout',
#  'Fielder4 Runout Missed',
#  'Fielder4 Runout Assist',
#  'Fielder4 Runout Assist Missed',
#  'Fielder4 Missed Stumping',
#  'Fielder4 Extra Effort',
#  'Fielder4 Pressure Field',
#  'Fielder4 Assist',
#  'Fielder4 Fumble',
#  'Fielder4 Misfield',
#  'Fielder4 Dive Stop',
#  'Fielder4 Dive Misfield',
#  'Fielder4 Slide Stop',
#  'Fielder4 Slide Miss',
#  'Fielder4 Throw',
#  'Fielder4 Good Throw',
#  'Fielder4 Error Throw',
#  'Fielder4 Throw Hit',
#  'Fielder4 Throw Miss',
#  'Fielder4 Throw Backed Up',
#  'Fielder4 Throw Not Backed Up',
#  'Fielder4 Keeper Drop',
#  'Fielder4 Keeper Fumble',
#  'Fielder4 Keeper Dive Stop',
#  'Fielder4 Keeper Missed Stumping',
#  'Fielder4 Keeper Leg Side',
#  'Fielder4 Event Grade',
#  'Fielder4 Event Infield',
#  'Fielder4 Runs Cost',
#  'Fielder4 Runs Saved',
#  'Fielder5 Catch',
#  'Fielder5 Catch Assist',
#  'Fielder5 Dropped Catch',
#  'Fielder5 Runout',
#  'Fielder5 Runout Missed',
#  'Fielder5 Runout Assist',
#  'Fielder5 Runout Assist Missed',
#  'Fielder5 Missed Stumping',
#  'Fielder5 Extra Effort',
#  'Fielder5 Pressure Field',
#  'Fielder5 Assist',
#  'Fielder5 Fumble',
#  'Fielder5 Misfield',
#  'Fielder5 Dive Stop',
#  'Fielder5 Dive Misfield',
#  'Fielder5 Slide Stop',
#  'Fielder5 Slide Miss',
#  'Fielder5 Throw',
#  'Fielder5 Good Throw',
#  'Fielder5 Error Throw',
#  'Fielder5 Throw Hit',
#  'Fielder5 Throw Miss',
#  'Fielder5 Throw Backed Up',
#  'Fielder5 Throw Not Backed Up',
#  'Fielder5 Keeper Drop',
#  'Fielder5 Keeper Fumble',
#  'Fielder5 Keeper Dive Stop',
#  'Fielder5 Keeper Missed Stumping',
#  'Fielder5 Keeper Leg Side',
#  'Fielder5 Event Grade',
#  'Fielder5 Event Infield',
#  'Fielder5 Runs Cost',
#  'Fielder5 Runs Saved',
#  'Video Start Time UTC',
#  'Video Stop Time UTC',
#  'Video UTC Offset Minutes',
#  'Video Start Time Local',
#  'Video Stop Time Local',
#  'Hit To Octant Description',
#  'Pitch X Description',
#  'Pitch Y Description',
#  'Pitch X Coded Description',
#  'Pitch Y Coded Description',
#  'Release X',
#  'Release Y',
#  'Release Z',
#  'Release Speed',
#  'Release Angle',
#  'Drop Speed',
#  'Drop Angle',
#  'Bounce Speed',
#  'Bounce Angle',
#  'Movement In Air',
#  'Movement Off Pitch',
#  'Stump Speed',
#  'Shot Aggression',
#  'Shot Quality Description',
#  'Hit To X Physical',
#  'Hit To Y Physical',
#  'Video Mark In Milliseconds',
#  'Keeper Id',
#  'Keeper']

# %% [markdown]
# 3. Check for duplicate rows.

# %%
# Print duplicate rows.
delivery_data[delivery_data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Match Id, Team Batting At Home, Team Bowling At Home, Toss Won By Team, Toss Won By Batting Team, Toss Decision, TeamA ResultId, Team Batting Id, Team Batting, Team Bowling Id, Team Bowling, Innings, Delivery, Day, Session, Time of Day (Hour), Time of Day (Min), Time of Day, Striker Id, Striker, Striker Hand Id, Striker Hand, Non Striker Id, Non Striker, Non Striker Hand Id, Non Striker Hand, Bowler Id, Bowler, Bowler Hand Id, Bowler Hand, Pace / Spin, Bowler Style, Spell, Over The Wicket, Northern End, Power Play, Over, Ball In Over, Fair Ball In Over, Ball Speed, Ball RPM, Pitch X, Pitch Y, At Batter X, At Batter Y, At Stumps X, At Stumps Y, Hit To Len, Hit To Angle, Bat Score, ReachedBoundary, Wides, Noballs, Byes, Legbyes, Penalty Runs, Taken By WK, Batter Out Id, Batter Out, How Out, Fielder1 Id, Fielder1, Fielder2 Id, Fielder2, Fielder3 Id, Fielder3, Fielder4 Id, Fielder4, Fielder5 Id, Fielder5, MatchInnings, TeamB ResultId, Team Batting ResultId, Team Batting Result, Team Bowling ResultId, Team Bowling Result, Temperature Id, Temperature Description, Humidity Id, Humidity Description, Wind Id, Wind Description, Cloud Cover Id, Cloud Cover Description, Cloud Colour Id, Cloud Colour Description, Inside Edge, Outside Edge, Play and Miss, Hit on Pads, Hit on Head, Hit on Body, Contact Error, Opportunity, Retired Hurt, Appeal, Bowler Variation, Batter Movement, Sweep Shot, Ramp or Paddle Shot, ...]
# Index: []
#
# [0 rows x 361 columns]

# %% [markdown]
# As there are no duplicate rows, there is no reason to perform any cleaning for this step.
#
# 4. Explore players that have played international one-day games.

# %%
# Determine IDs of international One-Day games.
odi_match_IDs = match_data[match_data.Series.str.contains("International") & match_data["Match Type Id"] == 1]["Match Id"]

# Extract deliveries within international One-Day games.
odi_deliveries = delivery_data[delivery_data["Match Id"].isin(odi_match_IDs)]

# Count number of international One Day games per player.
by_columns = ["Striker"]
aggregates = {"Match Id": pd.Series.nunique}
groupby_data = odi_deliveries.groupby(by=by_columns).agg(aggregates)
groupby_data
# Out:
#                         Match Id
# Striker
# Aamer, Mohammad                2
# Abbott, Kyle                   3
# Abbott, Sean                   3
# Adams, Andre                   2
# Adams, Jimmy                   5
# ...                          ...
# van Schoor, Melt               1
# van Troost, Luuk               2
# van der Dussen, Rassie         1
# van der Merwe, Roelof          4
# van der Wath, Johannes         3
#
# [916 rows x 1 columns]

# %% [markdown]
# Here we see two important factors that must be cleaned. Firstly, we are not interested in the batting careers of non-Australian players, so, we should strip the dataset to only include Australia's batting innings. Secondly, many players have only played a few innings. This is not reasonable to determine a players international performance, so, we must remove players that have played fewer than a threshold number of innings - 10 for example.
#
# 5. Explore the batting teams.

# %%
# Print all batting teams.
delivery_data["Team Batting"].unique()
# Out:
# array(['Pakistan (M)', 'Australia (M)', 'South Africa (M)',
#        'West Indies (M)', 'Zimbabwe (M)', 'Kenya (M)', 'New Zealand (M)',
#        'Bangladesh (M)', 'Sri Lanka (M)', 'England (M)', 'SA (M)',
#        'Victoria (M)', 'NSW (M)', 'Tas (M)', 'WA (M)', 'Qld (M)',
#        'India (M)', 'Ireland (M)', 'Scotland (M)', 'Netherlands (M)',
#        'Australia A (M)', 'USA (M)', 'ICC World XI (M)', 'Namibia (M)',
#        'Brisbane Heat (M)', 'Sydney Sixers (M)', 'Melbourne Stars (M)',
#        'Sydney Thunder (M)', 'Adelaide Strikers (M)',
#        'Melbourne Renegades (M)', 'Hobart Hurricanes (M)',
#        'Perth Scorchers  (M)', 'Canada (M)', 'South Africa A (M)',
#        'India A (M)', 'Afghanistan (M)', 'England Lions (M)', 'CA XI (M)',
#        'Board President XI (M)', 'India B (M)'], dtype=object)

# %% [markdown]
# This demonstrates the issue of many non-Australian players being recorded.
#
# 6. Explore players that have played for multiple countries.

# %%
# Count number of international teams per player.
by_columns = ["Striker"]
aggregates = {"Team Batting": pd.Series.nunique}
groupby_data = odi_deliveries.groupby(by=by_columns).agg(aggregates)

# Extract players that have played for multiple countries.
multiple_country_batters = groupby_data[groupby_data["Team Batting"] > 1]

# Display players that have played for multiple countries.
multiple_country_batters
# Out:
#                        Team Batting
# Striker
# Abbott, Kyle                      2
# Abbott, Sean                      2
# Afridi, Shahid                    2
# Agar, Ashton                      2
# Agarwal, Mayank                   4
# ...                             ...
# Wade, Matthew                     2
# White, Cameron                    2
# Zampa, Adam                       2
# van Jaarsveld, Vaughn             2
# van der Merwe, Roelof             2
#
# [95 rows x 1 columns]

# %%
odi_deliveries[odi_deliveries["Striker"] == "Agarwal, Mayank"]["Team Batting"].unique()
# Out:
# array(['India A (M)', 'Board President XI (M)', 'India B (M)',
#        'India (M)'], dtype=object)

# %% [markdown]
# As we can see, a player can play for multiple teams. Often, this is a player playing for different levels of international cricket for the one country. This is not necessarily the same for all players - for example, Luke Ronchi has played for NZ and AUS. We can address this issue by removing deliveries that are not bowled to an Australian team, rather than removing deliveries to a player that has played for multiple international teams. In the case of Luke Ronchi, this would mean removing his NZ performances, but not Australian.
